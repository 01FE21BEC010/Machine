# %% [markdown]
# my first program

# %%
print("i am ashwini")
# Out:
# i am ashwini

# %%
a+b

# %% [markdown]
# variable declaration in python

# %%
a=5
b=9
sum=a+b
print(sum)
print("sum")
# Out:
# 14
# sum

# %% [markdown]
# substraction

# %%
a=9
b=5
sub=a-b
print(sub)
print("sub")
# Out:
# 4
# sub

# %% [markdown]
# **substraction with 3 variable**

# %%
a=9
b=5
c=2
sub=a-b-c
print(sub)
print("sub")
# Out:
# 2
# sub

# %% [markdown]
# multiplication

# %%
a=3
b=4
mul=a*b
print(mul)
print("mul")
# Out:
# 12
# mul

# %% [markdown]
# division

# %%
a=10
b=2
quotient=a//b
remainder=a%b
print("quotient")
print(quotient)
print("remainder")
print(remainder)
# Out:
# quotient
# 5
# remainder
# 0

# %% [markdown]
# squaring of number

# %%
a=25
squ=a**2
print("squ")
print(squ)
# Out:
# squ
# 625

# %% [markdown]
# square root

# %%
import math
math.sqrt(25)
# Out:
# 5.0

# %% [markdown]
# **cube number**

# %%
a=25
cub=a**3
print(cub)
# Out:
# 15625
